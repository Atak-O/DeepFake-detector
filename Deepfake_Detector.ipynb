# %% [markdown]
# # DeepFake detector by Atak-O
#
# --Used Kaggle data-set:
# [link text](https://www.kaggle.com/datasets/saurabhbagchi/deepfake-image-detection)

# %% [markdown]
# **Libraries**
# :Install the libraries

# %%
# !pip install -q tf-keras==2.19.0 h5py==3.11.0

# %%
import tf_keras as keras  # tf-keras import – Keras version compatible with .h5 files.
from tf_keras.models import load_model  # Importing the load_model function within tf_keras allows us to expand this model.
from PIL import Image, ImageOps  # We are importing the Image and ImageOps classes from the Pillow library.
from google.colab import files

# %% [markdown]
# **Ana Fonksiyon**

# %%
def detect_deepfake(image):


  # 1. Upload the model and labels.
  model = load_model("keras_model.h5", compile=False)
  class_names = open("labels.txt", "r", encoding="utf-8").readlines()

  # 2. Set the photo to be tested.
  image = Image.open(image).convert("RGB")

  # 3.Resize the image to the 224x224 resolution required by the model.
  size = (224, 224)
  image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

  # 4.Convert the image to a series and normalize it.
  image_array = np.asarray(image)
  normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
  data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
  data[0] = normalized_image_array

  # 5. Make a prediction
  prediction = model.predict(data)
  index = np.argmax(prediction)
  class_name = class_names[index].strip()
  confidence_score = prediction[0][index]

  # print the result
  print(f"Sonuç: {class_name[2:]}") # To delete the number at the beginning [2:]
  print(f"Güven Skoru: %{confidence_score * 100:.2f}")
  return(class_name[2:].strip())

# %%
def main():
    path = files.upload()
    path = list(path.keys())[0]
    image = Image.open(path)
    class_name  = detect_deepfake(path)

    if class_name == "Fake":
        print("This image is a deepfake you mustn't trust and believe to this image!")
    else:
        print("This image is a real image you can trust and believe this image")

    print("Important Information! Please pay attention:THIS IS A TRAINED AI MODEL AND AI'S CAN MAKE MISTAKES DON'T TRULY TRUST THE PREDICTIONS OF THIS MODEL!")

# %%
main()
# Out:
#      <input type="file" id="files-c681d831-93e3-4e46-838a-317bc1bf9e42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c681d831-93e3-4e46-838a-317bc1bf9e42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
